# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.1.42-py3-none-any.whl (749 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 1.2 MB/s eta 0:00:00
# ...

# %%
# !pip install tqdm

# %%
import os
import shutil
import random
from tqdm.notebook import tqdm

# %%
pwd
# Out:
# '/content'

# %%
train_path_img="./yolo_data/images/train/"
train_path_label="./yolo_data/labels/train/"
val_path_img="./yolo_data/images/val/"
val_path_label="./yolo_data/labels/val/"

# %%
random.seed(42)

# %%
def train_test_split(path,split=0.2):
  files = list(set([name[:-4] for name in os.listdir(path)]))
  #print(files)
  print(f"Folder contains {len(files)} images")
  random.shuffle(files)
  test_size = int(len(files)*split)
  train_size = len(files)-test_size

  #creating directories

  os.makedirs(train_path_img,exist_ok=True)
  os.makedirs(train_path_label,exist_ok=True)
  os.makedirs(val_path_img,exist_ok=True)
  os.makedirs(val_path_label,exist_ok=True)



  for file in tqdm(files[:train_size]):
    shutil.copy2(path+'/'+file+'.jpg',f"{train_path_img}/"+file+'.jpg')
    shutil.copy2(path+'/'+file+'.txt',f"{train_path_label}/"+file+'.txt')


  for file in tqdm(files[train_size:]):
    shutil.copy2(path+'/'+file+'.jpg',f"{val_path_img}/"+file+'.jpg')
    shutil.copy2(path+'/'+file+'.txt',f"{val_path_label}/"+file+'.txt')


  # for file in files:
  #   print(file)

# %%
train_test_split('/content/drive/MyDrive/YOLO_V8/data')
# Out:
# Folder contains 66 images
# ...
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
len(os.listdir("/content/drive/MyDrive/YOLO_V8/data"))
# Out:
# 132

# %%
# !yolo task =detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/YOLO_V8/dataset.yaml batch=8 epochs=10 project =/content/drive/MyDrive/YOLO_V8/training_results name=football
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 147MB/s]
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/YOLO_V8/training_results/football/weights/best.pt conf=0.55 source=/content/drive/MyDrive/YOLO_V8/test_images
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/6 /content/drive/MyDrive/YOLO_V8/test_images/test_img1.jpg: 384x640 13 players, 386.6ms
# image 2/6 /content/drive/MyDrive/YOLO_V8/test_images/test_img2.jpg: 384x640 12 players, 1 football, 341.0ms
# image 3/6 /content/drive/MyDrive/YOLO_V8/test_images/test_img3.jpg: 384x640 13 players, 528.8ms
# image 4/6 /content/drive/MyDrive/YOLO_V8/test_images/test_img4.jpg: 384x640 12 players, 500.5ms
# image 5/6 /content/drive/MyDrive/YOLO_V8/test_images/test_img5.jpg: 384x640 11 players, 1 football, 340.6ms
# image 6/6 /content/drive/MyDrive/YOLO_V8/test_images/test_img6.jpg: 384x640 7 players, 339.4ms
# Speed: 3.6ms preprocess, 406.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/YOLO_V8/output

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/YOLO_V8/training_results/football/weights/best.pt conf=0.55 source=/content/drive/MyDrive/YOLO_V8/vid2
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/2 (frame 1/352) /content/drive/MyDrive/YOLO_V8/vid2/test_video1.mp4: 384x640 6 players, 379.4ms
# video 1/2 (frame 2/352) /content/drive/MyDrive/YOLO_V8/vid2/test_video1.mp4: 384x640 6 players, 396.0ms
# video 1/2 (frame 3/352) /content/drive/MyDrive/YOLO_V8/vid2/test_video1.mp4: 384x640 6 players, 365.5ms
# video 1/2 (frame 4/352) /content/drive/MyDrive/YOLO_V8/vid2/test_video1.mp4: 384x640 7 players, 376.8ms
# video 1/2 (frame 5/352) /content/drive/MyDrive/YOLO_V8/vid2/test_video1.mp4: 384x640 7 players, 363.3ms
# video 1/2 (frame 6/352) /content/drive/MyDrive/YOLO_V8/vid2/test_video1.mp4: 384x640 7 players, 387.2ms
# video 1/2 (frame 7/352) /content/drive/MyDrive/YOLO_V8/vid2/test_video1.mp4: 384x640 8 players, 376.3ms
# ...

# %%
# !cp -r /content/runs/detect/predict2 /content/drive/MyDrive/YOLO_V8/videos
